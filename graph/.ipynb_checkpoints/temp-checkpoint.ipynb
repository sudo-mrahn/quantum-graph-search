# %%
import numpy as np
import networkx as nx
from make import complete, barabasi
from attributes import get_eigs_sym, degrees_of, check_symmetric
import matplotlib.pyplot as plt
from process import bye_nb, bye_st

# %%
adj = complete(1000)

# %%
# %timeit bye_st(adj, 10)
# Out:
# 597 ms ± 4.44 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %timeit bye_nb(adj, 0, 10)
# Out:
# 579 µs ± 3.87 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
var = 1
while not var > 100:
    var += 1

# %%
var
# Out:
# 101
